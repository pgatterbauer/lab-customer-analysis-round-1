# %% [markdown]
# # Lab | Customer Analysis Round 1
#
# #### Remember the process:
#
# 1. Case Study
# 2. Get data
# 3. Cleaning/Wrangling/EDA
# 4. Processing Data
# 5. Modeling
# 6. Validation
# 7. Reporting
#
# ### Abstract
#
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 _csv_ files that are provided in the `files_for_lab` folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# ### Instructions
#
# √ Read the three files into python as dataframes
# √ Show the DataFrame's shape.
# √ Standardize header names.
# √ Rearrange the columns in the dataframe as needed
# √ Concatenate the three dataframes
# √ Which columns are numerical? income, monthly premium auto, total claim amount
# √ Which columns are categorical? rest excl numerical
# √ Understand the meaning of all columns
# √ Perform the data cleaning operations mentioned so far in class
#
#   - Delete the column education and the number of open complaints from the dataframe.
#   - Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.
#   - Check for duplicate rows in the data and remove if any.
#   - Filter out the data for customers who have an income of 0 or less.

# %% [markdown]
# for this lab, we will gather the data from 3 _csv_ files that are provided in the `files_for_lab` folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# ### Instructions
#
# - Read the three files into python as dataframes

# %%
import pandas as pd
file1 = pd.read_csv('files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('files_for_lab/csv_files/file3.csv')

# %%
file1.shape, file2.shape, file3.shape
# Out:
# ((4008, 11), (996, 11), (7070, 11))

# %%
file1.columns = file1.columns.str.lower()

# %%
file2.columns = file2.columns.str.lower()

# %%
file3.columns = file3.columns.str.lower()

# %%
print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file2=file2.reindex(columns= ['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'vehicle class', 'total claim amount'])
file3=file3.reindex(columns= ['customer', 'state', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'vehicle class', 'total claim amount'])

# %%
print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file3 = file3.rename(columns={"state":"st"})
file3.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
complete_file = pd.concat([file1, file2, file3])

# %%
complete_file
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
complete_file.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
complete_file.describe(include = "all")
# Out:
#        customer          st gender education  customer lifetime value  \
# count      9137        9137   9015      9137               9130.00000
# unique     9056           8      5         6               8211.00000
# top     QD28391  California      F  Bachelor              16468.22079
# freq          2        3032   4560      2719                  6.00000
# mean        NaN         NaN    NaN       NaN                      NaN
# std         NaN         NaN    NaN       NaN                      NaN
# min         NaN         NaN    NaN       NaN                      NaN
# 25%         NaN         NaN    NaN       NaN                      NaN
# 50%         NaN         NaN    NaN       NaN                      NaN
# 75%         NaN         NaN    NaN       NaN                      NaN
# max         NaN         NaN    NaN       NaN                      NaN
#
#               income  monthly premium auto  number of open complaints  \
# ...

# %%
complete_file["customer lifetime value"].value_counts()
# Out:
# 16468.220790    6
# 5246.278375     6
# 22332.439460    6
# 4270.034394     6
# 5107.163002     6
#                ..
# 7477.176362     1
# 15700.284360    1
# 2968.077571     1
# 5452.171237     1
# 2611.836866     1
# Name: customer lifetime value, Length: 8211, dtype: int64

# %%
new_df = complete_file.copy()

# %%
new_df.shape
# Out:
# (12074, 11)

# %%
new_df.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
new_df = new_df.drop_duplicates()

# %%
new_df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
new_df.isna().sum()
# Out:
# customer                       1
# st                             1
# gender                       123
# education                      1
# customer lifetime value        8
# income                         1
# monthly premium auto           1
# number of open complaints      1
# policy type                    1
# vehicle class                  1
# total claim amount             1
# dtype: int64

# %% [markdown]
#   √ Delete the column education and the number of open complaints from the dataframe.
#   - Check for duplicate rows in the data and remove if any.
#   - Filter out the data for customers who have an income of 0 or less.

# %%
new_df = new_df.drop(['education', 'number of open complaints'], axis = 1)

# %% [markdown]
#   - Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.

# %%
new_df
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# x Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change `dtype` to `numerical` type.

# %%
new_df['customer lifetime value'] = new_df['customer lifetime value'].str.rstrip('%').astype(float)
#new_df['customer lifetime value'] = pd.to_numeric(new_df['customer lifetime value'], errors = "coerce")

# %%
new_df['customer lifetime value']
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer lifetime value, Length: 9135, dtype: float64

# %% [markdown]
#   - Check for duplicate rows in the data and remove if any.

# %%
new_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 9135, dtype: bool

# %%
# Count duplicate in a DataFrame
new_df.duplicated().sum()
# Count duplicate on certain columns
# df.duplicated(subset=['gender', 'st', 'customer lifetime value']).sum()
# Out:
# 4

# %%
#count non-duplicated rows
(~new_df.duplicated()).sum()
# Out:
# 9131

# %%
# Extract duplicate rows
# or new_df.loc[new_df.duplicated(), :] -> :] for all columns
new_df.loc[new_df.duplicated()]
# Out:
#      customer          st gender  customer lifetime value   income  \
# 998   TO60700  Washington      F                      NaN  25859.0
# 1471  RI52095  Washington      M                      NaN  51878.0
# 1487  MW80236  Washington      M                      NaN      0.0
# 1535  SP81997  Washington      F                      NaN  41275.0
#
#       monthly premium auto    policy type  vehicle class  total claim amount
# 998                   74.0   Special Auto  Four-Door Car          355.200000
# 1471                  66.0  Personal Auto  Four-Door Car          316.800000
# 1487                  70.0  Personal Auto  Four-Door Car          336.000000
# 1535                  96.0  Personal Auto  Four-Door Car           41.122303

# %%
# delete duplicate rows
final_df = new_df.drop_duplicates()

# %%
final_df
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                697953.59      0.0
# 2     AI49188      Nevada      F               1288743.17  48767.0
# 3     WW63253  California      M                764586.18      0.0
# 4     GA49547  Washington      M                536307.65  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
